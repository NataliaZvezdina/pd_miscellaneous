# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['lunch'].count()
# Out:
# 1000

# %%
df[df['lunch'] == 'free/reduced']['lunch'].count() / df['lunch'].count()
# Out:
# 0.355

# %%
df['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
mean_wr_sc = df['writing score'].mean()
mean_wr_sc
# Out:
# 68.054

# %%
df[(df['gender'] == 'female') & (df['writing score'] > mean_wr_sc)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df['gender'] == 'female'][['math score', 'reading score']]
# Out:
#      math score  reading score
# 0            72             72
# 1            69             90
# 2            90             95
# 5            71             83
# 6            88             95
# ..          ...            ...
# 993          62             72
# 995          88             99
# 997          59             71
# 998          68             78
# 999          77             86
#
# [518 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df[df['lunch'] == 'standard'].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
df[df['lunch'] != 'standard'].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df.rename(columns = lambda x: x.replace(' ', '_'), inplace=True)

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.groupby(['gender', 'race/ethnicity'], as_index=False).agg({'math_score':['mean']})
# Out:
#    gender race/ethnicity math_score
#                                mean
# 0  female        group A  58.527778
# 1  female        group B  61.403846
# 2  female        group C  62.033333
# 3  female        group D  65.248062
# 4  female        group E  70.811594
# 5    male        group A  63.735849
# 6    male        group B  65.930233
# 7    male        group C  67.611511
# 8    male        group D  69.413534
# 9    male        group E  76.746479

# %%
df.sort_values(['gender', 'math_score'], ascending=False).groupby('gender')\
                        .head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
df['total_score'] = df['math_score'] + df['reading_score'] + df['writing_score']
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df = df.assign(total_score_log=np.log(df['total_score']))

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
df.drop(['total_score'], axis=1, inplace=True)
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score_log
# 0         5.384495
# 1         5.509388
# 2         5.627621
# 3         4.997212
# 4         5.433722

# %%
df.query('reading_score > 90')
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 2    female        group B             master's degree  standard
# 6    female        group B                some college  standard
# 102  female        group D          associate's degree  standard
# 106  female        group D             master's degree  standard
# 114  female        group E           bachelor's degree  standard
# ..      ...            ...                         ...       ...
# 957  female        group D             master's degree  standard
# 962  female        group E          associate's degree  standard
# 970  female        group D           bachelor's degree  standard
# 979  female        group C          associate's degree  standard
# 995  female        group E             master's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 2                      none          90             95             93
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
df.iloc[:5, :3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
df_with_names = df.iloc[[2, 8, 99, 105]]
df_with_names
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 8      male        group D                 high school  free/reduced
# 99   female        group D           bachelor's degree      standard
# 105  female        group C                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 2                      none          90             95             93
# 8                 completed          64             64             67
# 99                     none          65             67             62
# 105                    none          58             67             72

# %%
df_with_names.index = ['Mary', 'Gregory', 'Natalie', 'Charlotte']
df_with_names
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# Mary       female        group B             master's degree      standard
# Gregory      male        group D                 high school  free/reduced
# Natalie    female        group D           bachelor's degree      standard
# Charlotte  female        group C                some college      standard
#
#           test preparation course  math score  reading score  writing score
# Mary                         none          90             95             93
# Gregory                 completed          64             64             67
# Natalie                      none          65             67             62
# Charlotte                    none          58             67             72

# %%
df_with_names.loc[['Natalie', 'Charlotte'], ['gender', 'math score']]
# Out:
#            gender  math score
# Natalie    female          65
# Charlotte  female          58

# %%
df_with_names.iloc[:, 0]
# Out:
# Mary         female
# Gregory        male
# Natalie      female
# Charlotte    female
# Name: gender, dtype: object

# %%
series_1 = pd.Series([11, 22, 33], index=['Natalie', 'Charlotte', 'Gregory'])

# %%
series_2 = pd.Series([800, 900, 1000], index=['Natalie', 'Charlotte', 'Gregory'])

pd.DataFrame({'col_1':series_1, 'col_2':series_2})
# Out:
#            col_1  col_2
# Natalie       11    800
# Charlotte     22    900
# Gregory       33   1000

# %%
df_with_names[['lunch']]
# Out:
#                   lunch
# Mary           standard
# Gregory    free/reduced
# Natalie        standard
# Charlotte      standard

# %%
df_with_names[df_with_names['lunch'] == 'standard']
# Out:
#            gender race/ethnicity parental level of education     lunch  \
# Mary       female        group B             master's degree  standard
# Natalie    female        group D           bachelor's degree  standard
# Charlotte  female        group C                some college  standard
#
#           test preparation course  math score  reading score  writing score
# Mary                         none          90             95             93
# Natalie                      none          65             67             62
# Charlotte                    none          58             67             72

# %%
type(df_with_names['lunch'] == 'standard')
# Out:
# pandas.core.series.Series

# %%
titanic_df = pd.read_csv('/titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %%
titanic_df[['Survived', 'Pclass']].shape
# Out:
# (891, 2)

# %% [markdown]
# # dota_heroes_dataset

# %%
dota_df = pd.read_csv('/dota_hero_stats.csv')
dota_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_df.groupby(['attack_type', 'primary_attr'], as_index=False).agg({'id':['count']}).sort_values(('id', 'count'), ascending=False)
# Out:
#   attack_type primary_attr    id
#                            count
# 4      Ranged          int    40
# 2       Melee          str    35
# 0       Melee          agi    19
# 3      Ranged          agi    18
# 5      Ranged          str     3
# 1       Melee          int     2

# %%
dota_df.groupby('legs', as_index=False).agg({'id':['count']})
# Out:
#   legs    id
#        count
# 0    0    11
# 1    2    95
# 2    4     7
# 3    6     3
# 4    8     1

# %%
acc_df = pd.read_csv('/accountancy.csv')
acc_df.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
from os import access
acc_df.groupby(['Type', 'Executor'], as_index=False).agg({'Salary':['mean']})
# Out:
#    Type Executor      Salary
#                         mean
# 0     A    Loopa   58.000000
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 3     B     Pupa   77.000000
# 4     C    Loopa  154.333333
# 5     C     Pupa   74.500000
# 6     D    Loopa  137.714286
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 9     E     Pupa  131.200000
# 10    F    Loopa  238.000000
# 11    F     Pupa  136.250000

# %%
df_bio = pd.read_csv('/algae.csv')
df_bio.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
df__ = df_bio.groupby('group').agg({'sucrose':['max', 'min']})

# %% [markdown]
# Размах (максимум - минимум) сахарозы в бурых, зелёных и красных водорослях

# %%
df__['sucrose_diff'] = df__[('sucrose', 'max')] - df__[('sucrose', 'min')]
df__
# Out:
#         sucrose           sucrose_diff
#             max       min
# group
# brown  6.825467  1.636122     5.189345
# green  5.712284  2.452623     3.259662
# red    0.704580  0.704580     0.000000

# %% [markdown]
# Дисперсия концентрации цитрата в бурых, зелёных и красных водорослях ->

# %%
(df_bio.groupby('group')['citrate'].describe()['std']) ** 2
# Out:
# group
# brown    5.468942
# green    3.950113
# red           NaN
# Name: std, dtype: float64

# %% [markdown]
# Число видов бурых, зелёных и красных водорослей

# %%
df_bio.groupby('group')[['species']].nunique()
# Out:
#        species
# group
# brown        6
# green        3
# red          1

# %%
df_bio.groupby('genus').mean()
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
df_bio[df_bio['genus'] == 'Fucus'].describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165
